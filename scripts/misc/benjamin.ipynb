# %%
import psycopg2
import os 
import pandas as pd

# %%
data_path = "../../data"

# %%
from itertools import combinations


def find_primary_key_columns(df):
    """
    Find sets of columns that can serve as a primary key.

    Parameters:
    - df: The DataFrame to process.

    Returns:
    - A list of lists, where each inner list is a set of columns that can serve as a primary key.
    """
    # Get all column names
    columns = df.columns.tolist()

    # List to hold valid primary key column sets
    primary_key_sets = []

    # Check all non-empty subsets of columns
    for i in range(1, len(columns) + 1):
        for subset in combinations(columns, i):
            subset = list(subset)
            if (
                df.duplicated(subset).sum() == 0
            ):  # Check if all values are unique for this subset
                primary_key_sets.append(subset)
        if primary_key_sets != []:
            return primary_key_sets

    return primary_key_sets

# %%
file = os.path.join(data_path, "bilan-social-d-edf-sa-autres-conditions-de-travail.csv")
df = pd.read_csv(file, sep=";")
A = find_primary_key_columns(df)
for a in A:
    print(a)
# Out:
# ['Année', 'Indicateur', 'Type de contrat', 'Tranche horaire', 'Collège', 'Genre']
# ['Année', 'Indicateur', 'Type de contrat', 'Tranche horaire', 'Collège', 'Gender']
# ['Année', 'Indicateur', 'Type de contrat', 'Tranche horaire', 'Employee category', 'Genre']
# ['Année', 'Indicateur', 'Type de contrat', 'Tranche horaire', 'Employee category', 'Gender']
# ['Année', 'Indicateur', 'Type de contrat', 'Time range', 'Collège', 'Genre']
# ['Année', 'Indicateur', 'Type de contrat', 'Time range', 'Collège', 'Gender']
# ['Année', 'Indicateur', 'Type de contrat', 'Time range', 'Employee category', 'Genre']
# ['Année', 'Indicateur', 'Type de contrat', 'Time range', 'Employee category', 'Gender']
# ['Année', 'Indicateur', 'Type of contract', 'Tranche horaire', 'Collège', 'Genre']
# ['Année', 'Indicateur', 'Type of contract', 'Tranche horaire', 'Collège', 'Gender']
# ['Année', 'Indicateur', 'Type of contract', 'Tranche horaire', 'Employee category', 'Genre']
# ['Année', 'Indicateur', 'Type of contract', 'Tranche horaire', 'Employee category', 'Gender']
# ['Année', 'Indicateur', 'Type of contract', 'Time range', 'Collège', 'Genre']
# ['Année', 'Indicateur', 'Type of contract', 'Time range', 'Collège', 'Gender']
# ['Année', 'Indicateur', 'Type of contract', 'Time range', 'Employee category', 'Genre']
# ['Année', 'Indicateur', 'Type of contract', 'Time range', 'Employee category', 'Gender']
# ['Année', 'Indicator', 'Type de contrat', 'Tranche horaire', 'Collège', 'Genre']
# ['Année', 'Indicator', 'Type de contrat', 'Tranche horaire', 'Collège', 'Gender']
# ['Année', 'Indicator', 'Type de contrat', 'Tranche horaire', 'Employee category', 'Genre']
# ['Année', 'Indicator', 'Type de contrat', 'Tranche horaire', 'Employee category', 'Gender']
# ['Année', 'Indicator', 'Type de contrat', 'Time range', 'Collège', 'Genre']
# ['Année', 'Indicator', 'Type de contrat', 'Time range', 'Collège', 'Gender']
# ['Année', 'Indicator', 'Type de contrat', 'Time range', 'Employee category', 'Genre']
# ['Année', 'Indicator', 'Type de contrat', 'Time range', 'Employee category', 'Gender']
# ['Année', 'Indicator', 'Type of contract', 'Tranche horaire', 'Collège', 'Genre']
# ['Année', 'Indicator', 'Type of contract', 'Tranche horaire', 'Collège', 'Gender']
# ['Année', 'Indicator', 'Type of contract', 'Tranche horaire', 'Employee category', 'Genre']
# ['Année', 'Indicator', 'Type of contract', 'Tranche horaire', 'Employee category', 'Gender']
# ['Année', 'Indicator', 'Type of contract', 'Time range', 'Collège', 'Genre']
# ['Année', 'Indicator', 'Type of contract', 'Time range', 'Collège', 'Gender']
# ['Année', 'Indicator', 'Type of contract', 'Time range', 'Employee category', 'Genre']
# ['Année', 'Indicator', 'Type of contract', 'Time range', 'Employee category', 'Gender']

# %%
file = os.path.join(data_path, "bilan-social-d-edf-sa-salaries-en-situation-de-handicap.csv")
df = pd.read_csv(file, sep=";")
A = find_primary_key_columns(df)
for a in A:
    print(a)
# Out:
# ['Année', 'Type de contrat', 'Collège', 'Genre']
# ['Année', 'Type de contrat', 'Collège', 'Gender']
# ['Année', 'Type de contrat', 'Employee category', 'Genre']
# ['Année', 'Type de contrat', 'Employee category', 'Gender']
# ['Année', 'Type of contract', 'Collège', 'Genre']
# ['Année', 'Type of contract', 'Collège', 'Gender']
# ['Année', 'Type of contract', 'Employee category', 'Genre']
# ['Année', 'Type of contract', 'Employee category', 'Gender']

# %%
file = os.path.join(data_path, "bilan-social-d-edf-sa-absenteisme.csv")
df2 = pd.read_csv(file, sep=";")
A = find_primary_key_columns(df2[df2.columns[~df2.columns.isin(["Indicateur", "Indicator"])]])
for a in A:
    print(a)

# %%
file = os.path.join(data_path, "bilan-social-d-edf-sa-effectifs-et-repartition-par-age-statut-et-sexe.csv")
df2 = pd.read_csv(file, sep=";")
A = find_primary_key_columns(df2[df2.columns[~df2.columns.isin(["Indicateur", "Indicator"])]])
for a in A:
    print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 file = os.path.join(data_path, "bilan-social-d-edf-sa-effectifs-et-repartition-par-age-statut-et-sexe.csv")
#       2 df2 = pd.read_csv(file, sep=";")
# ----> 3 A = find_primary_key_columns(df2[df2.columns[~df2.columns.isin(["Indicateur", "Indicator"])]])
#       4 for a in A:
#       5     print(a)
#
# Cell In[3], line 25, in find_primary_key_columns(df)
#      22 for subset in combinations(columns, i):
#      23     subset = list(subset)
#      24     if (
# ---> 25         df.duplicated(subset).sum() == 0
#      26     ):  # Check if all values are unique for this subset
#      27         primary_key_sets.append(subset)
#      28 if primary_key_sets != []:
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/pandas/core/frame.py:6958, in DataFrame.duplicated(self, subset, keep)
#    6956 else:
#    6957     vals = (col.values for name, col in self.items() if name in subset)
# -> 6958     labels, shape = map(list, zip(*map(f, vals)))
#    6960     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6961     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/pandas/core/frame.py:6926, in DataFrame.duplicated.<locals>.f(vals)
#    6925 def f(vals) -> tuple[np.ndarray, int]:
# -> 6926     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6927     return labels.astype("i8", copy=False), len(shape)
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)
#     807         verify=False,
#     808     )
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# KeyboardInterrupt:

# %%
df2
# Out:
# ['../../data/bilan-social-d-edf-sa-salaries-en-situation-de-handicap.csv',
#  '../../data/bilan-social-d-edf-sa-autres-conditions-de-travail.csv',
#  '../../data/bilan-social-d-edf-sa-droit-du-travail.csv',
#  '../../data/bilan-social-d-edf-sa-formation.csv',
#  '../../data/bilan-social-d-edf-sa-travailleurs-exterieurs.csv',
#  '../../data/bilan-social-d-edf-sa-remuneration-et-promotions.csv',
#  '../../data/README.md',
#  '../../data/bilan-social-d-edf-sa-absenteisme.csv',
#  '../../data/bilan-social-d-edf-sa-effectifs-et-repartition-par-age-statut-et-sexe.csv']

# %%
df
# Out:
#      Année Perimètre juridique Perimètre spatial Spatial perimeter  \
# 0     2023              EDF SA            France            France
# 1     2023              EDF SA            France            France
# 2     2023              EDF SA            France            France
# 3     2023              EDF SA            France            France
# 4     2023              EDF SA            France            France
# ..     ...                 ...               ...               ...
# 184   2017              EDF SA            France            France
# 185   2017              EDF SA            France            France
# 186   2017              EDF SA            France            France
# 187   2017              EDF SA            France            France
# 188   2017              EDF SA            France            France
#
#                                             Indicateur  \
# 0                    Salariés en situation de handicap
# 1                    Salariés en situation de handicap
# 2                    Salariés en situation de handicap
# 3    Salariés reconnus travailleurs handicapés suit...
# 4    Salariés reconnus travailleurs handicapés suit...
# ..                                                 ...
# 184                  Salariés en situation de handicap
# 185                  Salariés en situation de handicap
# 186                  Salariés en situation de handicap
# 187                  Salariés en situation de handicap
# 188  Salariés reconnus travailleurs handicapés suit...
#
#                                              Indicator      Type de contrat  \
# 0                          Employees with Disabilities          Statutaires
# 1                          Employees with Disabilities  Non Statutaires CDI
# 2                          Employees with Disabilities  Non Statutaires CDD
# 3    Employees Recognized as Disabled Workers Due t...          Statutaires
# 4    Employees Recognized as Disabled Workers Due t...  Non Statutaires CDD
# ..                                                 ...                  ...
# 184                        Employees with Disabilities  Non Statutaires CDI
# 185                        Employees with Disabilities  Non Statutaires CDD
# 186                        Employees with Disabilities  Non Statutaires CDD
# 187                        Employees with Disabilities  Non Statutaires CDD
# 188  Employees Recognized as Disabled Workers Due t...  Non Statutaires CDI
#
#              Type of contract    Collège Employee category  Genre  Gender  \
# 0                   Statutory      Cadre          Managers  Femme  Female
# 1     Permanent non-staturory   Maîtrise       Supervisors  Homme    Male
# 2    Fixed-term non-statutory      Cadre          Managers  Homme    Male
# 3                   Statutory   Maîtrise       Supervisors    NaN     NaN
# 4    Fixed-term non-statutory      Cadre          Managers    NaN     NaN
# ..                        ...        ...               ...    ...     ...
# 184   Permanent non-staturory  Exécution        Operatives  Femme  Female
# 185  Fixed-term non-statutory      Cadre          Managers  Homme    Male
# 186  Fixed-term non-statutory      Cadre          Managers  Femme  Female
# 187  Fixed-term non-statutory   Maîtrise       Supervisors  Femme  Female
# 188   Permanent non-staturory      Cadre          Managers    NaN     NaN
#
#      Valeur   Unité    Unit Chapitre du bilan social
# 0     343.0  nombre  number                   §1.7.1
# 1       0.0  nombre  number                   §1.7.1
# 2       0.0  nombre  number                   §1.7.1
# 3      49.0  nombre  number                   §1.7.2
# 4       0.0  nombre  number                   §1.7.2
# ..      ...     ...     ...                      ...
# 184     1.0  nombre  number                   §1.7.1
# 185     0.0  nombre  number                   §1.7.1
# 186     0.0  nombre  number                   §1.7.1
# 187    10.0  nombre  number                   §1.7.1
# 188     0.0  nombre  number                   §1.7.2
#
# [189 rows x 16 columns]

# %%
pdf_path = "../../data/bilan-social.pdf"

# %%
import pypdf_table_extraction
tables = pypdf_table_extraction.read_pdf(pdf_path)
tables

tables.export('foo.csv', f='csv', compress=True) # json, excel, html, markdown, sqlite

tables[0].parsing_report
{
    'accuracy': 99.02,
    'whitespace': 12.24,
    'order': 1,
    'page': 1
}
tables[0].to_csv('foo.csv') # to_json, to_excel, to_html, to_markdown, to_sqlite
tables[0].df # get a pandas DataFrame!
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pypdf_table_extraction
#       2 tables = pypdf_table_extraction.read_pdf('foo.pdf')
#       3 tables
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/pypdf_table_extraction/__init__.py:1
# ----> 1 from camelot import __version__  # noqa: F401
#       2 from camelot import format_string  # noqa F401
#       3 from camelot import formatter  # noqa F401
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/camelot/__init__.py:4
#       1 import logging
#       3 from .__version__ import __version__  # noqa D100, F400
# ----> 4 from .io import read_pdf
#       5 from .plotting import PlotMethods
#       8 # set up logging
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/camelot/io.py:9
#       5 from typing import Union
#       7 from pypdf._utils import StrByteType
# ----> 9 from .handlers import PDFHandler
#      10 from .utils import remove_extra
#      11 from .utils import validate_input
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/camelot/handlers.py:18
#      15 from pypdf import PdfWriter
#      16 from pypdf._utils import StrByteType
# ---> 18 from .core import TableList
#      19 from .parsers import Hybrid
#      20 from .parsers import Lattice
#
# File ~/Documents/repos/D4G_project/.venv/lib/python3.12/site-packages/camelot/core.py:16
#      13 from typing import Iterable
#      14 from typing import Iterator
# ---> 16 import cv2
#      17 import pandas as pd
#      20 if sys.version_info >= (3, 11):
#
# ModuleNotFoundError: No module named 'cv2'
